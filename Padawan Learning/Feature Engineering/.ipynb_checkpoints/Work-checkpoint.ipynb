# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('heart.csv')

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1].values

# %%
# Split dataset on train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ## MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
min_max = MinMaxScaler()
X_train_MinMaxScaled = min_max.fit_transform(X_train)
X_test_MinMaxScaled = min_max.transform(X_test)

# %% [markdown]
# ## Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
X_train_StandardScaler = std.fit_transform(X_train)
X_test_StandardScaler = std.transform(X_test)

# %% [markdown]
# # Imperio

# %% [markdown]
# ## Box-Cox Transformer

# %%
from imperio import BoxCoxTransformer
boxcox = BoxCoxTransformer()
boxcox.fit(X_train, y_train)
X_transformed = boxcox.transform(X_test.astype(float))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 4>()
#       2 boxcox = BoxCoxTransformer()
#       3 boxcox.fit(X_train, y_train)
# ----> 4 X_transformed = boxcox.transform(X_test.astype(float))
#
# File ~/.local/lib/python3.10/site-packages/imperio/BoxCox.py:75, in BoxCoxTransformer.transform(self, X, **fit_params)
#      73             return X_copy
#      74         else:
# ---> 75             return np.array([self.__apply_change(xi) for xi in X])
#      76 else:
#      77     raise ValueError(
#      78         f'Was passed an array with {X.shape[1]} feature, while where required {self.shape[1]} features')
#
# File ~/.local/lib/python3.10/site-packages/imperio/BoxCox.py:75, in <listcomp>(.0)
#      73             return X_copy
#      74         else:
# ---> 75             return np.array([self.__apply_change(xi) for xi in X])
#      76 else:
#      77     raise ValueError(
#      78         f'Was passed an array with {X.shape[1]} feature, while where required {self.shape[1]} features')
#
# File ~/.local/lib/python3.10/site-packages/imperio/BoxCox.py:45, in BoxCoxTransformer.__apply_change(self, value)
#      37 def __apply_change(self, value : float) -> float:
#      38     '''
#      39         The functions that transforms a scalar value.
#      40     :param value: float
#    (...)
#      43         The transformed value by BoxCoxTransformer.
#      44     '''
# ---> 45     return np.log(value) if self.l == 0 else (self.l ** (-1)) * (value ** self.l - 1)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'float'
